# %% [markdown]
# <a href="https://colab.research.google.com/github/sevgiorbay/introduction-to-python/blob/master/Python_kursu_2_g%C3%BCn_%C3%B6dev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Day2: Homework
list_odd=list(range(1,12,2))        # odd numbers list
list_even=list(range(2,13,2))       # even numbers list
list_new=list_odd+list_even         # merging the lists
list_new=[i*2 for i in list_new]    # creating new list (multiply 2. each values)
print(list_new)
for i in list_new:                  # printing types of each values 
  print(type(i))
# Out:
# [2, 6, 10, 14, 18, 22, 4, 8, 12, 16, 20, 24]
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
